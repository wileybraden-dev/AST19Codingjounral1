# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"
plt.rc("font", size=18)
#this cell is just importing numpy and matplotlib as their respective shorthands for latter use. It also reformats the text in the plots for a better viewing. 
#started 2/27/2026, finished __/__/2026

# %%
x = np.linspace(0,2*np.pi, 100)
#this cell is jsut defining x as a serries of 100 numbers going from 0 to 2pi

# %%
def exponent(x,a = 10 - np.pi, b = 1.5):
    y = a*np.exp(-b*x)
    return(y)
# In this cell I  made the function "exponent" which defined y as the equation given in the prompt, and defined a and b for the equation y

# %%
plt.plot(x, exponent(x,a = 10 - np.pi, b = 1.5))
plt.xlabel("x")
plt.ylabel("y")
plt.savefig(fname = "expgraph.png")
# This cell is just ploting x and y and giving the two axises labells, not too much.

# %%
sigma = np.linspace(2,.2,100)
scatter = np.random.normal(scale = sigma, size = 100)
print(scatter)
#This does almost exactly what the promt said, make a list of 100 points linearly going from 2 to .2 using np.linspace, and using np.random.normal to make the scatter.
# Out:
# [ 1.54390947e+00  1.94227737e+00  5.05896622e-01  2.54771347e+00
#  -1.91218269e+00  3.05804810e-01 -5.22664641e+00  2.94739876e+00
#   4.09166824e+00  2.72360958e+00  1.57388946e+00  1.53301873e+00
#  -7.86382187e-01  4.04028766e-01 -5.82697108e-01  2.95579803e+00
#   5.34793315e-01 -1.95651499e+00 -5.23942450e-01  4.62802419e-01
#  -1.86782273e+00 -1.96491520e+00 -6.61415117e-01 -4.49608510e-01
#   2.34708130e+00 -2.07786507e+00 -1.07037277e+00 -2.29705826e+00
#   7.14405167e-01 -6.46725699e-01  1.86014651e+00 -1.69519010e+00
#  -1.21175218e+00  4.42586384e-01 -2.73226103e-01 -2.32413638e+00
#  -6.24298022e-01 -3.05524851e+00 -7.10597673e-01  2.70481851e-01
#   1.29038592e-01  1.39348398e+00 -1.78301910e-01  1.22652438e+00
#  -1.62291260e+00 -1.22335068e+00  2.23882540e+00  1.22775235e+00
#   1.57050631e+00  2.09712324e-02 -2.88255788e+00 -2.74252679e-01
#  -3.57982602e-01  2.76345322e+00 -1.09083139e+00  9.97080131e-03
#   3.94745390e-01 -4.93051997e-03  5.30358291e-01  2.99973310e-01
#  -2.24358735e-01 -1.05507645e+00  2.35373392e-01 -1.09013635e+00
#   8.74348297e-01  6.21037945e-01  3.18722916e-01  4.07952379e-01
#   1.68712868e-01 -3.40592755e-01 -4.65467039e-01 -1.99863886e-01
#  -1.10626000e+00 -8.27477699e-01 -5.43355702e-01  9.87260216e-02
#  -1.58990970e-01 -3.89839052e-01 -1.01791569e+00 -4.94342140e-03
#   2.79365471e-01 -3.27526402e-01  3.48805697e-01  4.01449847e-02
#   7.14683180e-02  1.32987918e-01 -1.21956989e-02  6.69465257e-01
#   1.63002971e-01  1.39598132e-01  4.03088998e-01 -3.74172596e-01
#   1.82454158e-01 -1.72494066e-01  7.63590920e-02  1.47089174e-01
#   1.99775589e-01  1.37489645e-01 -1.26114563e-01 -9.00205632e-02]

# %%
plt.plot(x, exponent(x,a = 10 - np.pi, b = 1.5), color="blue", zorder = 1)
plt.errorbar(x, exponent(x,a = 10 - np.pi, b = 1.5), yerr = np.absolute(scatter), color ="red", zorder=0)
plt.xlabel("x")
plt.ylabel("y + scatter")
plt.savefig(fname = "expgraph.png")
#This cell is almost identical to the prior graph, having the same underlying graph which looks kind of squished, but using the errorbar style of graph and making the y error the scatter
#To make the core graph stand out I tried to make it a different color, but I couldn't figure that out so I just coppied the core graph and put it on top and made it blue.
